# %%
#import libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the CSV file
df = pd.read_csv('C:\\Users\\DELL\\Desktop\\earthquake_incidents_2020_2024.csv')
df.head()
# Out:
#       Date   Latitude   Longitude  Magnitude  Depth_km   Location
# 0  00:00.0 -44.395709   89.780563        3.9     399.1  Indonesia
# 1  34:32.7  87.778727   25.888393        5.8     608.0      Japan
# 2  09:05.5 -37.530767  175.048802        4.9     266.0  Indonesia
# 3  43:38.2  48.733656  -30.695102        6.8     260.7       Peru
# 4  18:10.9 -13.050783   91.391427        7.2     433.4       Peru

# %%
# Set up plot style
plt.style.use('ggplot')

# %%
# check datatypes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       100 non-null    object
#  1   Latitude   100 non-null    float64
#  2   Longitude  100 non-null    float64
#  3   Magnitude  100 non-null    float64
#  4   Depth_km   100 non-null    float64
#  5   Location   100 non-null    object
# dtypes: float64(4), object(2)
# memory usage: 4.8+ KB

# %%
# basic stats
df.describe()
# Out:
#          Latitude   Longitude   Magnitude    Depth_km
# count  100.000000  100.000000  100.000000  100.000000
# mean     1.734236    8.335766    5.497000  362.268000
# std     49.092959  100.892336    1.513939  206.217322
# min    -88.566407 -175.187634    2.500000    7.100000
# 25%    -36.930402  -54.288227    4.500000  160.375000
# 50%     -3.698821    9.477106    5.650000  387.750000
# 75%     51.374289   90.072869    6.800000  528.625000
# max     87.778727  176.118391    7.900000  689.700000

# %%
# Histogram for Magnitude
plt.figure(figsize=(6, 4))
sns.histplot(df['Magnitude'].dropna(), bins=20, color='steelblue', edgecolor='black')
plt.title('Distribution of Earthquake Magnitudes')
plt.xlabel('Magnitude')
plt.ylabel('Frequency')
plt.show()

# %%
# Histogram for Depth
plt.figure(figsize=(6, 4))
sns.histplot(df['Depth_km'].dropna(), bins=20, color='salmon', edgecolor='black')
plt.title('Distribution of Earthquake Depths (km)')
plt.xlabel('Depth (km)')
plt.ylabel('Frequency')
plt.show()

# %%
# Group by country
avg_magnitude = df.groupby('Location')['Magnitude'].mean().sort_values(ascending=False).head(10)

# Plot
plt.figure(figsize=(10, 5))
sns.barplot(x=avg_magnitude.index, y=avg_magnitude.values, color='green')
plt.title('Top 10 Countries with Highest Average Earthquake Magnitude')
plt.ylabel('Average Magnitude')
plt.xticks(rotation=45)
plt.show()
